# %%
pip install tmdb-python
# Out:
# Requirement already satisfied: tmdb-python in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (0.0.9)
# Requirement already satisfied: aiohttp in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from tmdb-python) (3.8.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from aiohttp->tmdb-python) (1.3.3)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from aiohttp->tmdb-python) (2.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from aiohttp->tmdb-python) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from aiohttp->tmdb-python) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from aiohttp->tmdb-python) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from aiohttp->tmdb-python) (1.3.1)
# Requirement already satisfied: asynctest==0.13.0 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from aiohttp->tmdb-python) (0.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from aiohttp->tmdb-python) (4.4.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from aiohttp->tmdb-python) (1.8.2)
# Requirement already satisfied: idna>=2.0 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from yarl<2.0,>=1.0->aiohttp->tmdb-python) (3.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "requests[security]"
# Out:
# Requirement already satisfied: requests[security] in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from requests[security]) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from requests[security]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from requests[security]) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from requests[security]) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyopenssl ndg-httpsclient pyasn1
# Out:
# Requirement already satisfied: pyopenssl in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (22.0.0)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: pyasn1 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (0.4.8)
# Requirement already satisfied: cryptography>=35.0 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from pyopenssl) (38.0.4)
# Requirement already satisfied: cffi>=1.12 in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from cryptography>=35.0->pyopenssl) (1.15.1)
# Requirement already satisfied: pycparser in /Users/harisnaveed/opt/miniconda3/envs/cse217a/lib/python3.7/site-packages (from cffi>=1.12->cryptography>=35.0->pyopenssl) (2.21)
# Installing collected packages: ndg-httpsclient
# Successfully installed ndg-httpsclient-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import config2 # to hide TMDB API keys
import requests # to make TMDB API calls
import locale # to format currency as USD
locale.setlocale( locale.LC_ALL, '' )
import json
import pandas as pd

api_key = config2.tmdb_api_key

# %%
response = requests.get('https://api.themoviedb.org/3/discover/movie?api_key='+ api_key + '&language=en-US&region=US&sort_by=popularity.desc&include_adult=false&include_video=false&page=10')

# %%
data = response.json()
for result in data['results']:
    columns = list(result.keys())
    break

# %%
movie_dataframe = pd.DataFrame(columns=columns)

# %%
movie_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              0 non-null      object
#  1   backdrop_path      0 non-null      object
#  2   genre_ids          0 non-null      object
#  3   id                 0 non-null      object
#  4   original_language  0 non-null      object
#  5   original_title     0 non-null      object
#  6   overview           0 non-null      object
#  7   popularity         0 non-null      object
#  8   poster_path        0 non-null      object
#  9   release_date       0 non-null      object
#  10  title              0 non-null      object
#  11  video              0 non-null      object
#  12  vote_average       0 non-null      object
#  13  vote_count         0 non-null      object
# dtypes: object(14)
# memory usage: 0.0+ bytes

# %%
for i in range(400):
    response = requests.get(f'https://api.themoviedb.org/3/discover/movie?api_key={api_key}&language=en-US&region=US&sort_by=popularity.desc&include_adult=false&include_video=false&page={i+1}').json()
    for result in response['results']:
        if result['original_language']=='en':
            movie_dataframe = movie_dataframe.append(result, ignore_index=True)

# %%
movie_dataframe
# Out:
#       adult                     backdrop_path                 genre_ids  \
# 0     False  /pxJbfnMIQQxCrdeLD0zQnWr6ouL.jpg              [28, 35, 53]
# 1     False   /22z44LPkMyf5nyyXvv8qQLsbom.jpg            [27, 9648, 53]
# 2     False  /jr8tSoJGj33XLgFBy6lmZhpGQNu.jpg       [16, 12, 35, 10751]
# 3     False  /xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg             [28, 12, 878]
# 4     False  /AsEgGeccI32SwMBkxpwhOkhbzmF.jpg         [28, 878, 53, 27]
# ...     ...                               ...                       ...
# 6654  False  /2sZ3SYWN4ApotMkDyG79Y5YkAhP.jpg                  [35, 18]
# 6655  False  /iphK3NP0bmQbLV4SndaOdpVBYgv.jpg              [18, 35, 14]
# 6656  False  /rDisgVROM22D7bs5SCbmOAUYmm1.jpg  [18, 10402, 9648, 10749]
# 6657  False  /q7sl4qm8WlogrZ3cJxzuN8WejM1.jpg                      [18]
# 6658  False  /fxcDcnITkYB0G5PHDzJOhGF9hFo.jpg          [35, 53, 80, 28]
#
#            id original_language                  original_title  \
# 0     1077280                en                        Die Hart
# 1      631842                en              Knock at the Cabin
# 2      315162                en    Puss in Boots: The Last Wish
# 3      505642                en  Black Panther: Wakanda Forever
# 4     1011679                en          Shark Side of the Moon
# ...       ...               ...                             ...
# 6654    10699                en                            Hero
# 6655    12797                en                      Ghost Town
# 6656    15392                en                      Crossroads
# 6657   160588                en                    Blue Jasmine
# 6658     9414                en     The Man Who Knew Too Little
#
#                                                overview  popularity  \
# 0     Follow a fictionalized version of Kevin Hart, ...    2687.814
# 1     While vacationing at a remote cabin, a young g...    2476.126
# 2     Puss in Boots discovers that his passion for a...    2700.624
# 3     Queen Ramonda, Shuri, M’Baku, Okoye and the Do...    2361.671
# 4     Decades ago, the USSR developed unkillable sha...    2070.625
# ...                                                 ...         ...
# 6654  Bernie Laplante is having a rough time. He's d...      14.479
# 6655  Bertram Pincus, a cranky, people-hating Manhat...      12.480
# 6656  A wanna-be blues guitar virtuoso seeks a long-...      13.728
# 6657  After experiencing a traumatic misfortune, Jas...      13.232
# 6658  An American gets a ticket for an audience part...      10.729
#
#                            poster_path release_date  \
# 0     /1EnBjTJ5utgT1OXYBZ8YwByRCzP.jpg   2023-02-24
# 1     /dm06L9pxDOL9jNSK4Cb6y139rrG.jpg   2023-02-03
# 2     /kuf6dutpsT0vSVehic3EZIqkOBt.jpg   2022-12-21
# 3     /sv1xJUazXeYqALzczSZ3O6nkH75.jpg   2022-11-11
# 4     /v5CfpzxoJDkZxjZAizClFdlEF0U.jpg   2022-08-12
# ...                                ...          ...
# 6654  /wD7D0B9U9ooanxyhtgLKaqM7www.jpg   1992-10-02
# 6655  /b8VS14DwpLlugTxVWSllYU0Gjn5.jpg   2008-09-19
# 6656  /2sMo7gwZ8L7KttiW210T0ueJ2eX.jpg   1986-03-14
# 6657  /zLdLiUJfueZBctdv8OvkmGXEHEC.jpg   2013-08-23
# 6658  /yVlIZa0u6CTN5LudxGX77Fk46iz.jpg   1997-11-14
#
#                                title  video  vote_average vote_count
# 0                           Die Hart  False           6.3        155
# 1                 Knock at the Cabin  False           6.5        959
# 2       Puss in Boots: The Last Wish  False           8.4       4453
# 3     Black Panther: Wakanda Forever  False           7.3       4004
# 4             Shark Side of the Moon  False           5.3         70
# ...                              ...    ...           ...        ...
# 6654                            Hero  False           6.4        389
# 6655                      Ghost Town  False           6.5        837
# 6656                      Crossroads  False           7.4        345
# 6657                    Blue Jasmine  False           7.0       3119
# 6658     The Man Who Knew Too Little  False           6.4        405
#
# [6659 rows x 14 columns]

# %%
genre_json_file = open('genres.json')

genre_data = json.load(genre_json_file)

genre_list = genre_data['genres']

# %%
def obtaining_genre_from_genre_ids(movie_dataframe,genre_list):
    genre_list_for_dataframe= list()
    for i in range(len(movie_dataframe)):
        genre_ids = movie_dataframe.loc[i,'genre_ids']
        genres = list()
        for i in genre_list:
            if i['id'] in genre_ids:
                genres.append(i['name'])
        genre_list_for_dataframe.append(genres)

    movie_dataframe['genres'] = genre_list_for_dataframe
    
    return movie_dataframe

# %%
def basedOnNumberCast(top_cast_per_film, num, response):
    for i in range(num):
        top_cast_per_film.append(response['cast'][i]['name'])
    return top_cast_per_film

# %%
def obtaining_actors_and_actresses(movie_dataframe):
    top_cast_for_dataframe = list()
    movie_ids = movie_dataframe['id']
    
    for movie_id in movie_ids:
        response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={api_key}&language=en-US').json()
        top_cast_per_film = list()
        
        #print(movie_id)
        if len(response['cast']) > 10:
            top_cast_per_film = basedOnNumberCast(top_cast_per_film, 10, response)
        else:
            top_cast_per_film = basedOnNumberCast(top_cast_per_film, len(response['cast']), response)
        print(top_cast_per_film)
        top_cast_for_dataframe.append(top_cast_per_film)
    
    movie_dataframe['top_cast']=top_cast_for_dataframe
    return movie_dataframe

# %%
def obtaining_actors_and_actresses2(movie_id):    
    response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={api_key}&language=en-US').json()
    top_cast_per_film = list()
        
    #print(movie_id)
    if 'cast' in response.keys():
        if len(response['cast']) > 10:
            top_cast_per_film = basedOnNumberCast(top_cast_per_film, 10, response)
        else:
            top_cast_per_film = basedOnNumberCast(top_cast_per_film, len(response['cast']), response)
        #print(top_cast_per_film)
    else:
        top_cast_per_film.append(None)
    
    return top_cast_per_film

# %%
def checking_response_len(movie_dataframe):
    movie_ids = movie_dataframe['id']
    
    for movie_id in movie_ids:
        response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}/credits?api_key={api_key}&language=en-US').json()
        if 'cast' not in response.keys():
            movie_dataframe.drop(movie_dataframe[movie_dataframe['id']==movie_id].index, inplace=True)
        else:
            continue
            
    return movie_dataframe

# %%
#movie_dataframe = checking_response_len(movie_dataframe=movie_dataframe)

# %%
movie_dataframe=obtaining_genre_from_genre_ids(movie_dataframe, genre_list)

# %%
movie_dataframe
# Out:
#       adult                     backdrop_path                 genre_ids  \
# 0     False  /pxJbfnMIQQxCrdeLD0zQnWr6ouL.jpg              [28, 35, 53]
# 1     False   /22z44LPkMyf5nyyXvv8qQLsbom.jpg            [27, 9648, 53]
# 2     False  /jr8tSoJGj33XLgFBy6lmZhpGQNu.jpg       [16, 12, 35, 10751]
# 3     False  /xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg             [28, 12, 878]
# 4     False  /AsEgGeccI32SwMBkxpwhOkhbzmF.jpg         [28, 878, 53, 27]
# ...     ...                               ...                       ...
# 6654  False  /2sZ3SYWN4ApotMkDyG79Y5YkAhP.jpg                  [35, 18]
# 6655  False  /iphK3NP0bmQbLV4SndaOdpVBYgv.jpg              [18, 35, 14]
# 6656  False  /rDisgVROM22D7bs5SCbmOAUYmm1.jpg  [18, 10402, 9648, 10749]
# 6657  False  /q7sl4qm8WlogrZ3cJxzuN8WejM1.jpg                      [18]
# 6658  False  /fxcDcnITkYB0G5PHDzJOhGF9hFo.jpg          [35, 53, 80, 28]
#
#            id original_language                  original_title  \
# 0     1077280                en                        Die Hart
# 1      631842                en              Knock at the Cabin
# 2      315162                en    Puss in Boots: The Last Wish
# 3      505642                en  Black Panther: Wakanda Forever
# 4     1011679                en          Shark Side of the Moon
# ...       ...               ...                             ...
# 6654    10699                en                            Hero
# 6655    12797                en                      Ghost Town
# 6656    15392                en                      Crossroads
# 6657   160588                en                    Blue Jasmine
# 6658     9414                en     The Man Who Knew Too Little
#
#                                                overview  popularity  \
# 0     Follow a fictionalized version of Kevin Hart, ...    2687.814
# 1     While vacationing at a remote cabin, a young g...    2476.126
# 2     Puss in Boots discovers that his passion for a...    2700.624
# 3     Queen Ramonda, Shuri, M’Baku, Okoye and the Do...    2361.671
# 4     Decades ago, the USSR developed unkillable sha...    2070.625
# ...                                                 ...         ...
# 6654  Bernie Laplante is having a rough time. He's d...      14.479
# 6655  Bertram Pincus, a cranky, people-hating Manhat...      12.480
# 6656  A wanna-be blues guitar virtuoso seeks a long-...      13.728
# 6657  After experiencing a traumatic misfortune, Jas...      13.232
# 6658  An American gets a ticket for an audience part...      10.729
#
#                            poster_path release_date  \
# 0     /1EnBjTJ5utgT1OXYBZ8YwByRCzP.jpg   2023-02-24
# 1     /dm06L9pxDOL9jNSK4Cb6y139rrG.jpg   2023-02-03
# 2     /kuf6dutpsT0vSVehic3EZIqkOBt.jpg   2022-12-21
# 3     /sv1xJUazXeYqALzczSZ3O6nkH75.jpg   2022-11-11
# 4     /v5CfpzxoJDkZxjZAizClFdlEF0U.jpg   2022-08-12
# ...                                ...          ...
# 6654  /wD7D0B9U9ooanxyhtgLKaqM7www.jpg   1992-10-02
# 6655  /b8VS14DwpLlugTxVWSllYU0Gjn5.jpg   2008-09-19
# 6656  /2sMo7gwZ8L7KttiW210T0ueJ2eX.jpg   1986-03-14
# 6657  /zLdLiUJfueZBctdv8OvkmGXEHEC.jpg   2013-08-23
# 6658  /yVlIZa0u6CTN5LudxGX77Fk46iz.jpg   1997-11-14
#
#                                title  video  vote_average vote_count  \
# 0                           Die Hart  False           6.3        155
# 1                 Knock at the Cabin  False           6.5        959
# 2       Puss in Boots: The Last Wish  False           8.4       4453
# 3     Black Panther: Wakanda Forever  False           7.3       4004
# 4             Shark Side of the Moon  False           5.3         70
# ...                              ...    ...           ...        ...
# 6654                            Hero  False           6.4        389
# 6655                      Ghost Town  False           6.5        837
# 6656                      Crossroads  False           7.4        345
# 6657                    Blue Jasmine  False           7.0       3119
# 6658     The Man Who Knew Too Little  False           6.4        405
#
#                                            genres
# 0                      [Action, Comedy, Thriller]
# 1                     [Horror, Mystery, Thriller]
# 2          [Adventure, Animation, Comedy, Family]
# 3            [Action, Adventure, Science Fiction]
# 4     [Action, Horror, Science Fiction, Thriller]
# ...                                           ...
# 6654                              [Comedy, Drama]
# 6655                     [Comedy, Drama, Fantasy]
# 6656             [Drama, Music, Mystery, Romance]
# 6657                                      [Drama]
# 6658            [Action, Comedy, Crime, Thriller]
#
# [6659 rows x 15 columns]

# %%
movie_dataframe['top_cast'] = movie_dataframe['id'].apply(obtaining_actors_and_actresses2)

# %%
movie_dataframe
# Out:
#       adult                     backdrop_path                 genre_ids  \
# 0     False  /pxJbfnMIQQxCrdeLD0zQnWr6ouL.jpg              [28, 35, 53]
# 1     False   /22z44LPkMyf5nyyXvv8qQLsbom.jpg            [27, 9648, 53]
# 2     False  /jr8tSoJGj33XLgFBy6lmZhpGQNu.jpg       [16, 12, 35, 10751]
# 3     False  /xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg             [28, 12, 878]
# 4     False  /AsEgGeccI32SwMBkxpwhOkhbzmF.jpg         [28, 878, 53, 27]
# ...     ...                               ...                       ...
# 6654  False  /2sZ3SYWN4ApotMkDyG79Y5YkAhP.jpg                  [35, 18]
# 6655  False  /iphK3NP0bmQbLV4SndaOdpVBYgv.jpg              [18, 35, 14]
# 6656  False  /rDisgVROM22D7bs5SCbmOAUYmm1.jpg  [18, 10402, 9648, 10749]
# 6657  False  /q7sl4qm8WlogrZ3cJxzuN8WejM1.jpg                      [18]
# 6658  False  /fxcDcnITkYB0G5PHDzJOhGF9hFo.jpg          [35, 53, 80, 28]
#
#            id original_language                  original_title  \
# 0     1077280                en                        Die Hart
# 1      631842                en              Knock at the Cabin
# 2      315162                en    Puss in Boots: The Last Wish
# 3      505642                en  Black Panther: Wakanda Forever
# 4     1011679                en          Shark Side of the Moon
# ...       ...               ...                             ...
# 6654    10699                en                            Hero
# 6655    12797                en                      Ghost Town
# 6656    15392                en                      Crossroads
# 6657   160588                en                    Blue Jasmine
# 6658     9414                en     The Man Who Knew Too Little
#
#                                                overview  popularity  \
# 0     Follow a fictionalized version of Kevin Hart, ...    2687.814
# 1     While vacationing at a remote cabin, a young g...    2476.126
# 2     Puss in Boots discovers that his passion for a...    2700.624
# 3     Queen Ramonda, Shuri, M’Baku, Okoye and the Do...    2361.671
# 4     Decades ago, the USSR developed unkillable sha...    2070.625
# ...                                                 ...         ...
# 6654  Bernie Laplante is having a rough time. He's d...      14.479
# 6655  Bertram Pincus, a cranky, people-hating Manhat...      12.480
# 6656  A wanna-be blues guitar virtuoso seeks a long-...      13.728
# 6657  After experiencing a traumatic misfortune, Jas...      13.232
# 6658  An American gets a ticket for an audience part...      10.729
#
#                            poster_path release_date  \
# 0     /1EnBjTJ5utgT1OXYBZ8YwByRCzP.jpg   2023-02-24
# 1     /dm06L9pxDOL9jNSK4Cb6y139rrG.jpg   2023-02-03
# 2     /kuf6dutpsT0vSVehic3EZIqkOBt.jpg   2022-12-21
# 3     /sv1xJUazXeYqALzczSZ3O6nkH75.jpg   2022-11-11
# 4     /v5CfpzxoJDkZxjZAizClFdlEF0U.jpg   2022-08-12
# ...                                ...          ...
# 6654  /wD7D0B9U9ooanxyhtgLKaqM7www.jpg   1992-10-02
# 6655  /b8VS14DwpLlugTxVWSllYU0Gjn5.jpg   2008-09-19
# 6656  /2sMo7gwZ8L7KttiW210T0ueJ2eX.jpg   1986-03-14
# 6657  /zLdLiUJfueZBctdv8OvkmGXEHEC.jpg   2013-08-23
# 6658  /yVlIZa0u6CTN5LudxGX77Fk46iz.jpg   1997-11-14
#
#                                title  video  vote_average vote_count  \
# 0                           Die Hart  False           6.3        155
# 1                 Knock at the Cabin  False           6.5        959
# 2       Puss in Boots: The Last Wish  False           8.4       4453
# 3     Black Panther: Wakanda Forever  False           7.3       4004
# 4             Shark Side of the Moon  False           5.3         70
# ...                              ...    ...           ...        ...
# 6654                            Hero  False           6.4        389
# 6655                      Ghost Town  False           6.5        837
# 6656                      Crossroads  False           7.4        345
# 6657                    Blue Jasmine  False           7.0       3119
# 6658     The Man Who Knew Too Little  False           6.4        405
#
#                                            genres  \
# 0                      [Action, Comedy, Thriller]
# 1                     [Horror, Mystery, Thriller]
# 2          [Adventure, Animation, Comedy, Family]
# 3            [Action, Adventure, Science Fiction]
# 4     [Action, Horror, Science Fiction, Thriller]
# ...                                           ...
# 6654                              [Comedy, Drama]
# 6655                     [Comedy, Drama, Fantasy]
# 6656             [Drama, Music, Mystery, Romance]
# 6657                                      [Drama]
# 6658            [Action, Comedy, Crime, Thriller]
#
#                                                top_cast
# 0     [Kevin Hart, John Travolta, Nathalie Emmanuel,...
# 1     [Dave Bautista, Jonathan Groff, Ben Aldridge, ...
# 2     [Antonio Banderas, Salma Hayek, Harvey Guillén...
# 3     [Letitia Wright, Lupita Nyong'o, Danai Gurira,...
# 4     [Maxi Witrak, Ego Mikitas, Michael Marcel, Tan...
# ...                                                 ...
# 6654  [Dustin Hoffman, Geena Davis, Andy García, Joa...
# 6655  [Ricky Gervais, Greg Kinnear, Téa Leoni, Billy...
# 6656  [Ralph Macchio, Joe Seneca, Jami Gertz, Joe Mo...
# 6657  [Alec Baldwin, Cate Blanchett, Louis C.K., Bob...
# 6658  [Bill Murray, Peter Gallagher, Joanne Whalley,...
#
# [6659 rows x 16 columns]

# %%
movie_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6659 entries, 0 to 6658
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              6659 non-null   object
#  1   backdrop_path      6588 non-null   object
#  2   genre_ids          6659 non-null   object
#  3   id                 6659 non-null   object
#  4   original_language  6659 non-null   object
#  5   original_title     6659 non-null   object
#  6   overview           6659 non-null   object
#  7   popularity         6659 non-null   float64
#  8   poster_path        6640 non-null   object
#  9   release_date       6659 non-null   object
#  10  title              6659 non-null   object
#  11  video              6659 non-null   object
#  12  vote_average       6659 non-null   float64
#  13  vote_count         6659 non-null   object
#  14  genres             6659 non-null   object
#  15  top_cast           6659 non-null   object
# dtypes: float64(2), object(14)
# memory usage: 832.5+ KB

# %%
def keyword_func(movie_id):
    response = requests.get(f'https://api.themoviedb.org/3/movie/{movie_id}/keywords?api_key={api_key}').json()
    keywords_list = list()
    for i in response['keywords']:
        keywords_list.append(i['name'])
        
    return keywords_list

# %%
movie_dataframe['keywords'] = movie_dataframe['id'].apply(keyword_func)

# %%
movie_dataframe
# Out:
#       adult                     backdrop_path                 genre_ids  \
# 0     False  /pxJbfnMIQQxCrdeLD0zQnWr6ouL.jpg              [28, 35, 53]
# 1     False   /22z44LPkMyf5nyyXvv8qQLsbom.jpg            [27, 9648, 53]
# 2     False  /jr8tSoJGj33XLgFBy6lmZhpGQNu.jpg       [16, 12, 35, 10751]
# 3     False  /xDMIl84Qo5Tsu62c9DGWhmPI67A.jpg             [28, 12, 878]
# 4     False  /AsEgGeccI32SwMBkxpwhOkhbzmF.jpg         [28, 878, 53, 27]
# ...     ...                               ...                       ...
# 6654  False  /2sZ3SYWN4ApotMkDyG79Y5YkAhP.jpg                  [35, 18]
# 6655  False  /iphK3NP0bmQbLV4SndaOdpVBYgv.jpg              [18, 35, 14]
# 6656  False  /rDisgVROM22D7bs5SCbmOAUYmm1.jpg  [18, 10402, 9648, 10749]
# 6657  False  /q7sl4qm8WlogrZ3cJxzuN8WejM1.jpg                      [18]
# 6658  False  /fxcDcnITkYB0G5PHDzJOhGF9hFo.jpg          [35, 53, 80, 28]
#
#            id original_language                  original_title  \
# 0     1077280                en                        Die Hart
# 1      631842                en              Knock at the Cabin
# 2      315162                en    Puss in Boots: The Last Wish
# 3      505642                en  Black Panther: Wakanda Forever
# 4     1011679                en          Shark Side of the Moon
# ...       ...               ...                             ...
# 6654    10699                en                            Hero
# 6655    12797                en                      Ghost Town
# 6656    15392                en                      Crossroads
# 6657   160588                en                    Blue Jasmine
# 6658     9414                en     The Man Who Knew Too Little
#
#                                                overview  popularity  \
# 0     Follow a fictionalized version of Kevin Hart, ...    2687.814
# 1     While vacationing at a remote cabin, a young g...    2476.126
# 2     Puss in Boots discovers that his passion for a...    2700.624
# 3     Queen Ramonda, Shuri, M’Baku, Okoye and the Do...    2361.671
# 4     Decades ago, the USSR developed unkillable sha...    2070.625
# ...                                                 ...         ...
# 6654  Bernie Laplante is having a rough time. He's d...      14.479
# 6655  Bertram Pincus, a cranky, people-hating Manhat...      12.480
# 6656  A wanna-be blues guitar virtuoso seeks a long-...      13.728
# 6657  After experiencing a traumatic misfortune, Jas...      13.232
# 6658  An American gets a ticket for an audience part...      10.729
#
#                            poster_path release_date  \
# 0     /1EnBjTJ5utgT1OXYBZ8YwByRCzP.jpg   2023-02-24
# 1     /dm06L9pxDOL9jNSK4Cb6y139rrG.jpg   2023-02-03
# 2     /kuf6dutpsT0vSVehic3EZIqkOBt.jpg   2022-12-21
# 3     /sv1xJUazXeYqALzczSZ3O6nkH75.jpg   2022-11-11
# 4     /v5CfpzxoJDkZxjZAizClFdlEF0U.jpg   2022-08-12
# ...                                ...          ...
# 6654  /wD7D0B9U9ooanxyhtgLKaqM7www.jpg   1992-10-02
# 6655  /b8VS14DwpLlugTxVWSllYU0Gjn5.jpg   2008-09-19
# 6656  /2sMo7gwZ8L7KttiW210T0ueJ2eX.jpg   1986-03-14
# 6657  /zLdLiUJfueZBctdv8OvkmGXEHEC.jpg   2013-08-23
# 6658  /yVlIZa0u6CTN5LudxGX77Fk46iz.jpg   1997-11-14
#
#                                title  video  vote_average vote_count  \
# 0                           Die Hart  False           6.3        155
# 1                 Knock at the Cabin  False           6.5        959
# 2       Puss in Boots: The Last Wish  False           8.4       4453
# 3     Black Panther: Wakanda Forever  False           7.3       4004
# 4             Shark Side of the Moon  False           5.3         70
# ...                              ...    ...           ...        ...
# 6654                            Hero  False           6.4        389
# 6655                      Ghost Town  False           6.5        837
# 6656                      Crossroads  False           7.4        345
# 6657                    Blue Jasmine  False           7.0       3119
# 6658     The Man Who Knew Too Little  False           6.4        405
#
#                                            genres  \
# 0                      [Action, Comedy, Thriller]
# 1                     [Horror, Mystery, Thriller]
# 2          [Adventure, Animation, Comedy, Family]
# 3            [Action, Adventure, Science Fiction]
# 4     [Action, Horror, Science Fiction, Thriller]
# ...                                           ...
# 6654                              [Comedy, Drama]
# 6655                     [Comedy, Drama, Fantasy]
# 6656             [Drama, Music, Mystery, Romance]
# 6657                                      [Drama]
# 6658            [Action, Comedy, Crime, Thriller]
#
#                                                top_cast  \
# 0     [Kevin Hart, John Travolta, Nathalie Emmanuel,...
# 1     [Dave Bautista, Jonathan Groff, Ben Aldridge, ...
# 2     [Antonio Banderas, Salma Hayek, Harvey Guillén...
# 3     [Letitia Wright, Lupita Nyong'o, Danai Gurira,...
# 4     [Maxi Witrak, Ego Mikitas, Michael Marcel, Tan...
# ...                                                 ...
# 6654  [Dustin Hoffman, Geena Davis, Andy García, Joa...
# 6655  [Ricky Gervais, Greg Kinnear, Téa Leoni, Billy...
# 6656  [Ralph Macchio, Joe Seneca, Jami Gertz, Joe Mo...
# 6657  [Alec Baldwin, Cate Blanchett, Louis C.K., Bob...
# 6658  [Bill Murray, Peter Gallagher, Joanne Whalley,...
#
#                                                keywords
# 0                                                    []
# 1     [based on novel or book, sacrifice, cabin, fai...
# 2     [fairy tale, talking dog, spin off, aftercredi...
# 3     [loss of loved one, hero, sequel, superhero, b...
# 4     [moon, shark attack, inspiration, astronaut, s...
# ...                                                 ...
# 6654  [identity, custody battle, jinx, reporter, ex-...
# 6655  [new york city, life and death, adultery, bus,...
# 6656                    [harmonica, blues, guitar duel]
# 6657  [new york city, sibling relationship, san fran...
# 6658  [london, england, bomb, sibling relationship, ...
#
# [6659 rows x 17 columns]

# %%
movie_dataframe.to_csv('tmdb_movie_info.csv', encoding='utf-8')
